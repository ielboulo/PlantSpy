# %%
#Package Kaggle
# !pip install -q kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#creation d'un fichier Kaggle
# !mkdir ~/.kaggle/
# Out:
# mkdir: cannot create directory ‘/root/.kaggle/’: File exists

# %%
# !cp '/content/drive/MyDrive/Kaggle/kaggle.json' ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d vbookshelf/v2-plant-seedlings-dataset

# %%
! kaggle datasets download -d vipoooool/new-plant-diseases-dataset
# Out:
# 401 - Unauthorized

# %%
! kaggle competitions download -c 'New Plant Diseases Dataset'
# Out:
# ...
# 401 - Unauthorized

# %%
! kaggle datasets download -d saroz014/plant-disease

# %%
! kaggle datasets download -d abdallahalidev/plantvillage-dataset
# Out:
# ...
#  99% 2.03G/2.04G [00:20<00:00, 49.9MB/s]
# 100% 2.04G/2.04G [00:20<00:00, 105MB/s]

# %%
! unzip /content/v2-plant-seedlings-dataset.zip -d /content/drive/MyDrive/Kaggle/v2-plant-seedlings-dataset

# %%
! unzip /content/new-plant-diseases-dataset.zip -d /content/drive/MyDrive/NewPlantDisease
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/NewPlantDisease/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/valid/Strawberry___healthy/273a7a9e-18be-4b6a-976a-fa5ffd69b731___RS_HL 4366_90deg.JPG
#   inflating: /content/drive/MyDrive/NewPlantDisease/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/valid/Strawberry___healthy/275f8963-f4f4-4903-962b-1da716725d08___RS_HL 4780_90deg.JPG
#   inflating: /content/drive/MyDrive/NewPlantDisease/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/valid/Strawberry___healthy/275f8963-f4f4-4903-962b-1da716725d08___RS_HL 4780_new30degFlipLR.JPG
#   inflating: /content/drive/MyDrive/NewPlantDisease/new plant diseases dataset(augmented)/New Plant Diseases Dataset(Augmented)/valid/Strawberry___healthy/27c2aaa4-de4b-4fb1-ba8d-14d4b24b2afa___RS_HL 4665.JPG
# ...

# %%
! unzip /content/plant-disease.zip -d /content/drive/MyDrive/Kaggle/plant-disease-dataset

# %%
! unzip /content/plantvillage-dataset.zip -d /content/drive/MyDrive/Kaggle/plantvillage-dataset
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Kaggle/plantvillage-dataset/plantvillage dataset/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6e345153-aed9-4879-a2cc-24f9dc5100e7___UF.GRC_YLCV_Lab 01798_final_masked.jpg
#   inflating: /content/drive/MyDrive/Kaggle/plantvillage-dataset/plantvillage dataset/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6e37e8ad-3944-4e11-bc10-dd82616274d7___YLCV_NREC 2915_final_masked.jpg
#   inflating: /content/drive/MyDrive/Kaggle/plantvillage-dataset/plantvillage dataset/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6e382244-fb3a-4caa-af71-05fff25f1c27___UF.GRC_YLCV_Lab 03397_final_masked.jpg
#   inflating: /content/drive/MyDrive/Kaggle/plantvillage-dataset/plantvillage dataset/segmented/Tomato___Tomato_Yellow_Leaf_Curl_Virus/6e3b9886-ce13-49d5-8f80-ccf4e5ddbeac___YLCV_GCREC 5479_final_masked.jpg
# ...

# %%
! zip /content/drive/MyDrive/Kaggle/plantvillage-dataset
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Kaggle/plantvillage-dataset, /content/drive/MyDrive/Kaggle/plantvillage-dataset.zip or /content/drive/MyDrive/Kaggle/plantvillage-dataset.ZIP.
