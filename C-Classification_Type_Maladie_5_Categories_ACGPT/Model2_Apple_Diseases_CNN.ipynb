# %% [markdown]
# # PlantSpy 2- Classification Type de maladie Apples

# %% [markdown]
# ## Importer les librairies et connection au Drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import cv2
import tensorflow as tf
import os
import pathlib
from PIL import Image 
from sklearn.model_selection import train_test_split
# %matplotlib inline

from matplotlib import cm

from imblearn.under_sampling import RandomUnderSampler

from tensorflow.keras.layers import Input, Dense 
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dropout 
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Conv2D 
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras import Sequential
from tensorflow.keras import callbacks

from tensorflow.keras.applications.vgg16 import VGG16


from sklearn import metrics # Pour évaluer les modèles

import itertools # Pour créer des iterateurs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Recuperation des donnees:

# %% [markdown]
# #### Train Dataset

# %%
# folder_path = "/content/drive/MyDrive/Kaggle/new-plant-diseases-dataset/train/"
folder_path = "/content/drive/MyDrive/NewPlantDiseasesDataset/train/"

X_train0=[]
y_train0=[]

width = 100
height = 100 # resize to 100x100 to solve the RAM issue in Kaggle notebooks

for path, dirs, files in os.walk(folder_path):
    for repertoire in dirs:
      if ("Apple" in repertoire) : 
        chemin=folder_path+repertoire
        for images in os.listdir(chemin):
          img=cv2.imread(chemin+'/'+images,cv2.IMREAD_COLOR )
          img_resized = cv2.resize(img, (width,height))
          X_train0.append(np.array(img_resized))
          y_train0.append(repertoire.split('___')[1])   # On recupere le type de maladie seulement

# %%
X_train0 = np.array(X_train0)
X_train0 = X_train0.astype('float32')

# %%
y_train0= np.array(y_train0)

# %%
X_train0.shape
# Out:
# (7771, 100, 100, 3)

# %%
print(pd.DataFrame(y_train0).value_counts())
# Out:
# Apple_scab          2016
# healthy             2008
# Black_rot           1987
# Cedar_apple_rust    1760
# dtype: int64

# %% [markdown]
# #### Valid Dataset

# %%
folder_path = "/content/drive/MyDrive/NewPlantDiseasesDataset/valid/"

X_valid0=[]
y_valid0=[]

width = 100
height = 100 # 

for path, dirs, files in os.walk(folder_path):
    for repertoire in dirs:
      if ("Apple" in repertoire) :
        chemin=folder_path+repertoire
        for images in os.listdir(chemin):
          img=cv2.imread(chemin+'/'+images,cv2.IMREAD_COLOR )
          img_resized = cv2.resize(img, (width,height))
          X_valid0.append(np.array(img_resized))
          y_valid0.append(repertoire.split('___')[1])   # On recupere le type de maladie seulement

# %%
X_valid0= np.array(X_valid0)
X_valid0 = X_valid0.astype('float32')

y_valid0= np.array(y_valid0)

# %%
X_valid0.shape
# Out:
# (1943, 100, 100, 3)

# %%
pd.DataFrame(y_valid0).value_counts()
# Out:
# Apple_scab          504
# healthy             502
# Black_rot           497
# Cedar_apple_rust    440
# dtype: int64

# %% [markdown]
# ## DataViz

# %%
# Diviser les pixels des données X_train et X_test par 255 afin qu'ils soient compris entre 0 et 1
X_train = X_train0 / 255
X_valid = X_valid0 / 255

# %%
plt.subplots(2, 5, figsize=(16, 8))

j = 1

for i in np.random.choice(np.arange(0, len(X_train)), size = 10):
    # Image
    img =X_train[i]
    
    
    # Subplot nous permet de selectionner une des sous-figures parmi une grille. Dans notre cas la grille
    # a 2 lignes et 3 colonnes.
    plt.subplot(2, 5, j)
    j = j + 1
    
    # Suppresion des axes
    plt.axis('off')
    
    # Affichage de la figure
    plt.imshow(img, interpolation='None')

    # Modification du titre de la figure
    plt.title('Label: ' + str(y_train0[i]))

# %%
import seaborn as sns

plt.figure(figsize=(20, 10))

sns.countplot(y_train0)
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
pd.DataFrame(y_train0).value_counts()
# Out:
# Apple_scab          2016
# healthy             2008
# Black_rot           1987
# Cedar_apple_rust    1760
# dtype: int64

# %% [markdown]
# ## Preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
y_train = encoder.fit_transform(y_train0)
y_valid = encoder.transform(y_valid0)

# %%
# Pour retrouver facilement les noms des labels
dict_maladie_Apple = { 0: 'Apple_scab' ,
                 1: 'Black_rot' ,
                 2 : 'Cedar_apple_rust',
                 3 : 'healthy' }

list_maladie_Apple =[ 'Apple_scab', 'Black_rot' ,'Cedar_apple_rust' ,'healthy' ]

# %%
# Shape of X_train and y_train
print('Shape of X Train:', X_train.shape)
print('Shape of y train:',y_train.shape)

print('Shape of X valid:', X_valid.shape)
print('Shape of y valid:',y_valid.shape)
# Out:
# Shape of X Train: (7771, 100, 100, 3)
# Shape of y train: (7771,)
# Shape of X valid: (1943, 100, 100, 3)
# Shape of y valid: (1943,)

# %%
pd.DataFrame(y_train).value_counts()
# Out:
# 0    2016
# 3    2008
# 1    1987
# 2    1760
# dtype: int64

# %% [markdown]
# ## Callbacks

# %%
early_stopping = callbacks.EarlyStopping(monitor = 'val_loss',
                        patience = 8,
                        mode = 'min',
                        restore_best_weights = True)

lr_plateau = callbacks.ReduceLROnPlateau(monitor = 'val_loss',
                            patience=4,
                            factor=0.5,
                            verbose=2,
                            mode='min')

# %% [markdown]
# ## Generateur de donnees

# %%
train_data_generator = ImageDataGenerator(
        rotation_range=50,
        width_shift_range=1,
        height_shift_range=1,
        zoom_range=[0.7, 1.2],
        horizontal_flip=True)

test_data_generator = ImageDataGenerator()

# %%
batch_size = 50

training_data = train_data_generator.flow(X_train, y_train, batch_size=batch_size)
test_data = test_data_generator.flow(X_valid, y_valid, batch_size=batch_size)

# %% [markdown]
# # 1er Modele: Architecture LeNet avec generateur d'images

# %% [markdown]
# #### Architecture Lenet

# %%
input_shape = (100,100,3)

# %%
model_Apple = Sequential()
model_Apple.add(Conv2D(filters=30, kernel_size=(5, 5), padding='valid', input_shape=input_shape, activation='relu'))
model_Apple.add(MaxPooling2D(pool_size=(3, 3)))
model_Apple.add(Dropout(rate=0.2))
model_Apple.add(Conv2D(filters=64, kernel_size=(3, 3), padding='valid', activation='relu'))
model_Apple.add(MaxPooling2D(pool_size=(2, 2)))
model_Apple.add(Conv2D(filters=32, kernel_size=(3, 3), padding='valid', activation='relu'))
model_Apple.add(MaxPooling2D(pool_size=(2, 2)))
model_Apple.add(Dropout(rate=0.2))
model_Apple.add(Flatten())
model_Apple.add(Dense(units=64, activation='relu'))
model_Apple.add(Dense(units=4, activation='sigmoid'))# 4 ?

# %%
model_Apple.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model_Apple.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 96, 96, 30)        2280
#
#  max_pooling2d_3 (MaxPooling  (None, 32, 32, 30)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 30)        0
#
#  conv2d_4 (Conv2D)           (None, 30, 30, 64)        17344
#
#  max_pooling2d_4 (MaxPooling  (None, 15, 15, 64)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 32)        18464
#
#  max_pooling2d_5 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  dropout_3 (Dropout)         (None, 6, 6, 32)          0
#
#  flatten_1 (Flatten)         (None, 1152)              0
#
#  dense_2 (Dense)             (None, 64)                73792
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 112,140
# Trainable params: 112,140
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_Apple1 = model_Apple.fit_generator(generator = training_data, 
                              epochs = 20,
                              steps_per_epoch = len(X_train)//batch_size,
                              validation_data = test_data,
                              validation_steps = len(X_valid)//batch_size,
                              callbacks = [early_stopping,lr_plateau])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/20
# 155/155 [==============================] - 64s 406ms/step - loss: 0.9458 - accuracy: 0.5805 - val_loss: 0.5379 - val_accuracy: 0.7768 - lr: 0.0010
# Epoch 2/20
# 155/155 [==============================] - 63s 406ms/step - loss: 0.5554 - accuracy: 0.7748 - val_loss: 0.6461 - val_accuracy: 0.7453 - lr: 0.0010
# Epoch 3/20
# 155/155 [==============================] - 63s 405ms/step - loss: 0.4937 - accuracy: 0.8083 - val_loss: 0.4640 - val_accuracy: 0.8068 - lr: 0.0010
# Epoch 4/20
# 155/155 [==============================] - 64s 412ms/step - loss: 0.4187 - accuracy: 0.8382 - val_loss: 0.5105 - val_accuracy: 0.8053 - lr: 0.0010
# Epoch 5/20
# 155/155 [==============================] - 62s 401ms/step - loss: 0.3941 - accuracy: 0.8494 - val_loss: 0.3580 - val_accuracy: 0.8542 - lr: 0.0010
# Epoch 6/20
# 155/155 [==============================] - 62s 402ms/step - loss: 0.3275 - accuracy: 0.8771 - val_loss: 0.3970 - val_accuracy: 0.8453 - lr: 0.0010
# Epoch 7/20
# 155/155 [==============================] - 63s 406ms/step - loss: 0.3007 - accuracy: 0.8868 - val_loss: 0.2251 - val_accuracy: 0.9137 - lr: 0.0010
# Epoch 8/20
# 155/155 [==============================] - 64s 411ms/step - loss: 0.2756 - accuracy: 0.8956 - val_loss: 0.4565 - val_accuracy: 0.8421 - lr: 0.0010
# Epoch 9/20
# 155/155 [==============================] - 63s 407ms/step - loss: 0.2384 - accuracy: 0.9131 - val_loss: 0.2097 - val_accuracy: 0.9105 - lr: 0.0010
# Epoch 10/20
# 155/155 [==============================] - 62s 401ms/step - loss: 0.2420 - accuracy: 0.9097 - val_loss: 0.3346 - val_accuracy: 0.8800 - lr: 0.0010
# Epoch 11/20
# 155/155 [==============================] - 63s 404ms/step - loss: 0.2244 - accuracy: 0.9176 - val_loss: 0.2415 - val_accuracy: 0.9058 - lr: 0.0010
# Epoch 12/20
# 155/155 [==============================] - 63s 407ms/step - loss: 0.1785 - accuracy: 0.9336 - val_loss: 0.1329 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 13/20
# 155/155 [==============================] - 62s 401ms/step - loss: 0.1699 - accuracy: 0.9396 - val_loss: 0.3917 - val_accuracy: 0.8674 - lr: 0.0010
# Epoch 14/20
# 155/155 [==============================] - 63s 403ms/step - loss: 0.1520 - accuracy: 0.9440 - val_loss: 0.2403 - val_accuracy: 0.9200 - lr: 0.0010
# Epoch 15/20
# 155/155 [==============================] - 62s 402ms/step - loss: 0.1408 - accuracy: 0.9490 - val_loss: 0.1232 - val_accuracy: 0.9537 - lr: 0.0010
# Epoch 16/20
# 155/155 [==============================] - 64s 409ms/step - loss: 0.1728 - accuracy: 0.9360 - val_loss: 0.2236 - val_accuracy: 0.9163 - lr: 0.0010
# Epoch 17/20
# 155/155 [==============================] - 62s 399ms/step - loss: 0.1424 - accuracy: 0.9474 - val_loss: 0.1766 - val_accuracy: 0.9284 - lr: 0.0010
# Epoch 18/20
# 155/155 [==============================] - 62s 400ms/step - loss: 0.1279 - accuracy: 0.9542 - val_loss: 0.1439 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 19/20
# 155/155 [==============================] - ETA: 0s - loss: 0.1102 - accuracy: 0.9608
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 155/155 [==============================] - 62s 400ms/step - loss: 0.1102 - accuracy: 0.9608 - val_loss: 0.1414 - val_accuracy: 0.9511 - lr: 0.0010
# Epoch 20/20
# 155/155 [==============================] - 63s 404ms/step - loss: 0.0854 - accuracy: 0.9690 - val_loss: 0.0684 - val_accuracy: 0.9758 - lr: 5.0000e-04

# %%
model_Apple.save('/content/drive/MyDrive/model_Apple_Healthy')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/model_Apple_Healthy/assets

# %%
plt.figure(figsize=(12,4))
plt.subplot(121)
plt.plot(history_Apple1.history['loss'])
plt.plot(history_Apple1.history['val_loss'])
plt.title('Model loss by epoch')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right')

plt.subplot(122)
plt.plot(history_Apple1.history['accuracy'])
plt.plot(history_Apple1.history['val_accuracy'])
plt.title('Model acc by epoch')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='right');

# %%
test_pred_Apple1 = model_Apple.predict(X_valid)

test_pred_Apple1_class = test_pred_Apple1.argmax(axis = 1)

# %%
test_pred_Apple1_label = encoder.inverse_transform(test_pred_Apple1_class)
y_valid_label =encoder.inverse_transform( y_valid)

# %%
print(metrics.classification_report(y_valid_label, test_pred_Apple1_label))
# Out:
#                   precision    recall  f1-score   support
#
#       Apple_scab       0.97      0.96      0.97       504
#        Black_rot       0.95      1.00      0.97       497
# Cedar_apple_rust       1.00      0.99      1.00       440
#          healthy       0.99      0.95      0.97       502
#
#         accuracy                           0.98      1943
#        macro avg       0.98      0.98      0.98      1943
#     weighted avg       0.98      0.98      0.98      1943

# %%
# Matrice de Confusion

cnf_matrix = metrics.confusion_matrix(y_valid_label, test_pred_Apple1_label)

classes = range(0,4)
plt.figure(figsize=(10, 10))


plt.imshow(cnf_matrix, interpolation='nearest',cmap='Blues')
plt.title("Matrice de confusion")
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)

for i, j in itertools.product(range(cnf_matrix.shape[0]), range(cnf_matrix.shape[1])):
    plt.text(j, i, cnf_matrix[i, j],
             horizontalalignment="center",
             color="white" if cnf_matrix[i, j] > ( cnf_matrix.max() / 2) else "black")

plt.yticks([0,1,2, 3], list_maladie_Apple )
plt.ylabel('Vrais labels')
plt.xticks([0,1,2, 3],list_maladie_Apple,
                  rotation = 90)

plt.xlabel('Labels prédits')

plt.show()
